# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0
import cufflinks as cf
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
# 4.14.3
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Exploring the data

# %%
df = pd.read_csv('steps.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1570 entries, 0 to 1569
# Data columns (total 6 columns):
# date            1570 non-null object
# lastSyncTime    1570 non-null int64
# steps           1570 non-null int64
# distance        1570 non-null int64
# runDistance     1570 non-null int64
# calories        1570 non-null int64
# dtypes: int64(5), object(1)
# memory usage: 73.7+ KB

# %%
df.count()
# Out:
# date            1570
# lastSyncTime    1570
# steps           1570
# distance        1570
# runDistance     1570
# calories        1570
# dtype: int64

# %%
df.head()
# Out:
#          date  lastSyncTime  steps  distance  runDistance  calories
# 0  2016-04-27    1461794594   4948      3242           46       281
# 1  2016-04-28    1461910351  16573     12060           79       751
# 2  2016-04-29    1461969057  18002     12916           29       737
# 3  2016-04-30    1462058218   4126      2981           11       207
# 4  2016-05-01    1462206634   3869      2651            0       244

# %%
df.tail()
# Out:
#             date  lastSyncTime  steps  distance  runDistance  calories
# 1565  2020-08-09    1597012143   7408      5078          452       158
# 1566  2020-08-10    1597097941   8456      5724          517       182
# 1567  2020-08-11    1597187297   7792      5664          220       191
# 1568  2020-08-12    1597270081   7789      5532          443       189
# 1569  2020-08-13    1597356483   1968      1380           96        45

# %%
sns.set_style('whitegrid')
sns.pairplot(df.head(100))

# %%
plt.figure(figsize = (15,10))
sns.heatmap(df.corr(), annot = True,linewidths=1, linecolor='white',)
